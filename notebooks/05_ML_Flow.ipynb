# %% [markdown]
# Bharat Garg (iitp_aiml_2506250 )

# %%
import mlflow
import mlflow.sklearn
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# %%
mlflow.set_experiment("credit_risk_classification")

# %%
from pathlib import Path
import sys
import pickle

import numpy as np
import pandas as pd

# Make sure we can import src.*
PROJECT_ROOT = Path("..").resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.feature_engineering import evaluate_model, log_model_to_mlflow

# Load test data
X_test = pd.read_csv("../data/processed/X_test.csv")
y_test = pd.read_csv("../data/processed/y_test.csv").values.ravel()

models_dir = PROJECT_ROOT / "models"
figures_dir = PROJECT_ROOT / "reports" / "figures"
figures_dir.mkdir(parents=True, exist_ok=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 13
#      10 if str(PROJECT_ROOT) not in sys.path:
#      11     sys.path.insert(0, str(PROJECT_ROOT))
# ---> 13 from src.feature_engineering import evaluate_model, log_model_to_mlflow
#      15 # Load test data
#      16 X_test = pd.read_csv("../data/processed/X_test.csv")
#
# File D:\projects\credit-risk-ml-pipeline\src\feature_engineering.py:13
#      10 from __future__ import annotations
#      12 import pandas as pd
# ---> 13 from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
#      14 import mlflow
#      15 import mlflow.sklearn
#
# File c:\Users\bhara\.conda\envs\creditRisk\Lib\site-packages\sklearn\__init__.py:70
#      62 # `_distributor_init` allows distributors to run custom init code.
#      63 # For instance, for the Windows wheel, this is used to pre-load the
#      64 # vcomp shared library runtime for OpenMP embedded in the sklearn/.libs
#    (...)
#      67 # later is linked to the OpenMP runtime to make it possible to introspect
#      68 # it and importing it first would fail if the OpenMP dll cannot be found.
#      69 from sklearn import __check_build, _distributor_init  # noqa: E402 F401
# ---> 70 from sklearn.base import clone  # noqa: E402
#      71 from sklearn.utils._show_versions import show_versions  # noqa: E402
#      73 _submodules = [
#      74     "calibration",
#      75     "cluster",
#    (...)
#     111     "compose",
#     112 ]
#
# File c:\Users\bhara\.conda\envs\creditRisk\Lib\site-packages\sklearn\base.py:20
#      18 from sklearn.exceptions import InconsistentVersionWarning
#      19 from sklearn.utils._metadata_requests import _MetadataRequester, _routing_enabled
# ---> 20 from sklearn.utils._missing import is_pandas_na, is_scalar_nan
#      21 from sklearn.utils._param_validation import validate_parameter_constraints
#      22 from sklearn.utils._repr_html.base import ReprHTMLMixin, _HTMLDocumentationLinkMixin
#
# File c:\Users\bhara\.conda\envs\creditRisk\Lib\site-packages\sklearn\utils\__init__.py:9
#       7 from sklearn.utils import metadata_routing
#       8 from sklearn.utils._bunch import Bunch
# ----> 9 from sklearn.utils._chunking import gen_batches, gen_even_slices
#      11 # Make _safe_indexing importable from here for backward compat as this particular
#      12 # helper is considered semi-private and typically very useful for third-party
#      13 # libraries that want to comply with scikit-learn's estimator API. In particular,
#      14 # _safe_indexing was included in our public API documentation despite the leading
#      15 # `_` in its name.
#      16 from sklearn.utils._indexing import _safe_indexing, resample, shuffle
#
# File c:\Users\bhara\.conda\envs\creditRisk\Lib\site-packages\sklearn\utils\_chunking.py:11
#       8 import numpy as np
#      10 from sklearn._config import get_config
# ---> 11 from sklearn.utils._param_validation import Interval, validate_params
#      14 def chunk_generator(gen, chunksize):
#      15     """Chunk generator, ``gen`` into lists of length ``chunksize``. The last
#      16     chunk may have a length less than ``chunksize``."""
#
# File c:\Users\bhara\.conda\envs\creditRisk\Lib\site-packages\sklearn\utils\_param_validation.py:17
#      14 from scipy.sparse import csr_matrix, issparse
#      16 from sklearn._config import config_context, get_config
# ---> 17 from sklearn.utils.validation import _is_arraylike_not_scalar
#      20 class InvalidParameterError(ValueError, TypeError):
#      21     """Custom exception to be raised when the parameter of a class/method/function
#      22     does not have a valid type or value.
#      23     """
#
# File c:\Users\bhara\.conda\envs\creditRisk\Lib\site-packages\sklearn\utils\validation.py:24
#      18 from sklearn import get_config as _get_config
#      19 from sklearn.exceptions import (
#      20     DataConversionWarning,
#      21     NotFittedError,
#      22     PositiveSpectrumWarning,
#      23 )
# ---> 24 from sklearn.utils._array_api import (
#      25     _asarray_with_order,
#      26     _convert_to_numpy,
#      27     _is_numpy_namespace,
#      28     _max_precision_float_dtype,
#      29     get_namespace,
#      30     get_namespace_and_device,
#      31 )
#      32 from sklearn.utils._dataframe import is_pandas_df, is_pandas_df_or_series
#      33 from sklearn.utils._isfinite import FiniteStatus, cy_isfinite
#
# File c:\Users\bhara\.conda\envs\creditRisk\Lib\site-packages\sklearn\utils\_array_api.py:20
#      18 from sklearn.externals.array_api_compat import numpy as np_compat
#      19 from sklearn.utils._dataframe import is_df_or_series
# ---> 20 from sklearn.utils.fixes import parse_version
#      22 # TODO: complete __all__
#      23 __all__ = ["xpx"]  # we import xpx here just to re-export it, need this to appease ruff
#
# File c:\Users\bhara\.conda\envs\creditRisk\Lib\site-packages\sklearn\utils\fixes.py:16
#      14 import scipy
#      15 import scipy.sparse.linalg
# ---> 16 import scipy.stats
#      18 try:
#      19     import pandas as pd
#
# File c:\Users\bhara\.conda\envs\creditRisk\Lib\site-packages\scipy\stats\__init__.py:628
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)
#     623
#     624 """  # noqa: E501
#     626 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     627                                DegenerateDataWarning, FitError)
# --> 628 from ._stats_py import *
#     629 from ._variation import variation
#     630 from .distributions import *
#
# File c:\Users\bhara\.conda\envs\creditRisk\Lib\site-packages\scipy\stats\_stats_py.py:40
#      37 from numpy import array, asarray, ma
#      39 from scipy import sparse
# ---> 40 from scipy.spatial import distance_matrix
#      42 from scipy.optimize import milp, LinearConstraint
#      43 from scipy._lib._util import _get_nan, _rename_parameter, _contains_nan, np_vecdot
#
# File c:\Users\bhara\.conda\envs\creditRisk\Lib\site-packages\scipy\spatial\__init__.py:124
#     120 from . import ckdtree, kdtree, qhull
#     122 __all__ = [s for s in dir() if not s.startswith('_')]
# --> 124 from . import distance, transform
#     126 __all__ += ['distance', 'transform']
#     128 from scipy._lib._testutils import PytestTester
#
# File c:\Users\bhara\.conda\envs\creditRisk\Lib\site-packages\scipy\spatial\transform\__init__.py:21
#       1 """
#       2 Spatial Transformations (:mod:`scipy.spatial.transform`)
#       3 ========================================================
#    (...)
#      18    RotationSpline
#      19 """
#      20 from ._rotation import Rotation, Slerp
# ---> 21 from ._rigid_transform import RigidTransform
#      22 from ._rotation_spline import RotationSpline
#      24 # Deprecated namespaces, to be removed in v2.0.0
#
# File c:\Users\bhara\.conda\envs\creditRisk\Lib\site-packages\scipy\spatial\transform\_rigid_transform.py:17
#       9 from scipy._lib._array_api import (
#      10     array_namespace,
#      11     is_numpy,
#    (...)
#      14     xp_capabilities,
#      15 )
#      16 from scipy.spatial.transform import Rotation
# ---> 17 from scipy.spatial.transform._rotation import _promote
#      18 import scipy.spatial.transform._rigid_transform_cy as cython_backend
#      19 import scipy.spatial.transform._rigid_transform_xp as xp_backend
#
# ImportError: cannot import name '_promote' from 'scipy.spatial.transform._rotation' (c:\Users\bhara\.conda\envs\creditRisk\Lib\site-packages\scipy\spatial\transform\_rotation.cp311-win_amd64.pyd)

# %%
with open(models_dir / "logistic_regression_tuned.pkl", "rb") as f:
    lr_t = pickle.load(f)
with open(models_dir / "decision_tree_tuned.pkl", "rb") as f:
    dt_t = pickle.load(f)
with open(models_dir / "random_forest_tuned.pkl", "rb") as f:
    rf_t = pickle.load(f)
with open(models_dir / "xgboost_tuned.pkl", "rb") as f:
    xgb_t = pickle.load(f)

# %%
y_pred_lr_t = lr_t.predict(X_test);        y_proba_lr_t = lr_t.predict_proba(X_test)[:, 1]
y_pred_dt_t = dt_t.predict(X_test);        y_proba_dt_t = dt_t.predict_proba(X_test)[:, 1]
y_pred_rf_t = rf_t.predict(X_test);        y_proba_rf_t = rf_t.predict_proba(X_test)[:, 1]
y_pred_xgb_t = xgb_t.predict(X_test);      y_proba_xgb_t = xgb_t.predict_proba(X_test)[:, 1]

# %%
# Log all models to MLflow
log_model_to_mlflow(lr_t, "Logistic_Regression", X_test, y_test, y_pred_lr_t, y_proba_lr_t)
log_model_to_mlflow(dt_t, "Decision_Tree", X_test, y_test, y_pred_dt_t, y_proba_dt_t)
log_model_to_mlflow(rf_t, "Random_Forest", X_test, y_test, y_pred_rf_t, y_proba_rf_t)
log_model_to_mlflow(xgb_t, "XGBoost", X_test, y_test, y_pred_xgb_t, y_proba_xgb_t)

print("Models successfully logged to MLflow! Run `mlflow ui` to view the results.")
